# %% [markdown]
# # ASSIGNMENT 3

# %% [markdown]
# 1.L=[1,23,’hello’,1]
# print(type(L))   a)list b)integer c)string d)None of the above

# %% [markdown]
# Answer : a) list

# %% [markdown]
# 2. L=[10,20,30] print(L[1]*L[-1]) a)Error b)300 c)200 d)600

# %% [markdown]
# Answer : d) 600

# %% [markdown]
# 3. Find the minimum and maximum values of given list? my_list=[34,45,563,435,656,435,767,34,5676,45,2,2,2,3556,65]

# %%
my_list=[34,45,563,435,656,435,767,34,5676,45,2,2,2,3556,65]

max_val = max(my_list)
min_val = min(my_list) 

print(f"the min value in th list is {min_val}") 
print(f"the max value in th list is {max_val}")
# Out:
# the min value in th list is 2
# the max value in th list is 5676

# %% [markdown]
# 4. Write a python program to get the product of all elements in a list?

# %%
a_list = [1, 4, 1, 3, 2]

product = 1

for x in a_list:
  product = product * x 

print(product)
# Out:
# 24

# %% [markdown]
# 5. Write a Python program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings(create your own list and do the rest)?

# %%
new_list = ["hello", "anna", "is", "going", "to", "a", "123", "after", "noon"]

tot_same = 0

for i in new_list:
  if len(i) >=2 and i[0] == i[-1]:
    tot_same += 1

print(f"no.of string whose len is 2 or more and first and last char are same = {tot_same}")
# Out:
# no.of string whose len is 2 or more and first and last char are same = 3

# %% [markdown]
#  6. Write a program to remove the duplicates from the given list? samp_list = [10, 20, 30, 20, 10, 50, 60, 40, 80, 50, 40]

# %%
samp_list = [10, 20, 30, 20, 10, 50, 60, 40, 80, 50, 40]
samp_list = list(set(samp_list)) #set doesn't contain duplicates

print(samp_list)
# Out:
# [40, 10, 80, 50, 20, 60, 30]
