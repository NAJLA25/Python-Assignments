# %% [markdown]
# #ASSIGNMENT 4

# %% [markdown]
# 1. Create a list which consist of tuples. Create a tuple from multiple data types?

# %% [markdown]
# 2. Create a tuple which contains numbers from 1 to 20 and replace every even values with letter ‘e’ ?

# %% [markdown]
# 3. Create a tuple with months in a year and add/append names of days in a week into it?
